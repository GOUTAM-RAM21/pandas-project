# %% [markdown]
# <a href="https://colab.research.google.com/github/GOUTAM-RAM21/pandas-project/blob/main/data_fetch_api.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import requests

# %%
response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1')

# %%
 response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/9Sd3RuIbnFCA4SX8CiBsp4x1XPd.jpg',
#   'genre_ids': [18, 53],
#   'id': 418437,
#   'original_language': 'en',
#   'original_title': 'Unforgettable',
#   'overview': "Barely coping with the end of her marriage, Tessa Connover learns that her ex-husband, David, is now happily engaged to Julia. Trying to settle into her new life after moving in with David, Julia believes she has finally met the man of her dreams, the man who can help her forget her troubled past. Soon, Tessa's jealousy starts to consume her, and she will stop at nothing to turn Julia's paradise into the ultimate nightmare.",
#   'popularity': 3.1494,
#   'poster_path': '/jKyjJu3N0bcF9TzcyGLb0Nn6Uqq.jpg',
#   'release_date': '2017-03-06',
#   'title': 'Unforgettable',
#   'video': False,
#   'vote_average': 5.9,
#   'vote_count': 667},
#  {'adult': False,
#   'backdrop_path': '/zSJT1sKGRKcmP4I9b8dIOuepw6I.jpg',
#   'genre_ids': [12, 28, 53, 14],
#   'id': 375588,
# ...

# %%
import pandas as pd

temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
display(temp_df.head())
# Out:
#        id                        title  \
# 0  418437                Unforgettable
# 1  375588                   Robin Hood
# 2   10708               Daddy Day Care
# 3    2310                      Beowulf
# 4  496704  Tremors: A Cold Day in Hell
#
#                                             overview release_date  popularity  \
# 0  Barely coping with the end of her marriage, Te...   2017-03-06      3.1494
# 1  A war-hardened Crusader and his Moorish comman...   2018-11-03      9.0250
# 2  Two men get laid off and have to become stay-a...   2003-05-09      2.4081
# 3  A 6th-century Scandinavian warrior named Beowu...   2007-11-05      6.5651
# 4  Burt Gummer and Travis Welker find themselves ...   2018-05-01      1.7407
#
#    vote_average  vote_count
# 0         5.900         667
# 1         5.917        3042
# 2         5.915        2170
# 3         5.915        2922
# 4         5.914         430

# %%
df = pd.DataFrame()
for i in range(1,429):
    response = requests.get('https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={}'.format(i))
    temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
    df = pd.concat([df, temp_df], ignore_index=True)

# %%
df.to_csv('movies.csv')
