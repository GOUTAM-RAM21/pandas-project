# %% [markdown]
# <a href="https://colab.research.google.com/github/GOUTAM-RAM21/pandas-project/blob/main/ml12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !mkdir -p ~/.kaggle
# !cp kaggle.json ~/.kaggle/

# %%
# !kaggle datasets download -d wobotintelligence/face-mask-detection-dataset
# Out:
# ...
# Dataset URL: https://www.kaggle.com/datasets/wobotintelligence/face-mask-detection-dataset
# License(s): CC0-1.0
# ...
# 100% 2.50G/2.50G [00:32<00:00, 250MB/s]
# 100% 2.50G/2.50G [00:32<00:00, 82.9MB/s]

# %%
import zipfile
zip_ref = zipfile.ZipFile('face-mask-detection-dataset.zip', 'r')
zip_ref.extractall('/content')
zip_ref.close()
